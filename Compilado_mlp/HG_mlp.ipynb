# %%
import pandas as pd

# %%
# Leer archivo excel por ruta
ruta = r"G:\.shortcut-targets-by-id\1ugEph6zRyoKHbwpiYuXbB3Pj0UXueIKJ\09. Contrato CS115 EIA 2024\03.WIP\02.Hidrología\01 Linea Base\02 Variables 2024\Caudales\2024\Analisis Devolución a Comunidad 2014-2023_JI_OK.xlsx"
df = pd.read_excel(ruta, sheet_name="Diario", header=7)

# %%
#borrar Fecha.1
df = df.drop(columns=['Fecha.1'])
df
# Out:
#                    Fecha  Mes   Año  Pelambres antes P Alternativa_L/S  \
# 0    2013-12-31 19:00:00   12  2013                          92.948117
# 1    2014-01-01 19:00:00    1  2014                         110.826366
# 2    2014-01-02 19:00:00    1  2014                         107.672999
# 3    2014-01-03 19:00:00    1  2014                         109.229445
# 4    2014-01-04 19:00:00    1  2014                         107.583905
# ...                  ...  ...   ...                                ...
# 3754 2024-04-11 00:00:00    4  2024                          32.393754
# 3755 2024-04-12 00:00:00    4  2024                          32.435304
# 3756 2024-04-13 00:00:00    4  2024                          34.812708
# 3757 2024-04-14 00:00:00    4  2024                          33.630122
# 3758 2024-04-15 00:00:00    4  2024                          58.565880
#
#       Río Blanco_L/S  Total Pelambres + Piuquenes_L/S  \
# 0         112.000000                       280.180722
# ...

# %%
columnas_a_conservar = ['MES', 'AÑO', 'Fecha', 'Vivero (Agrochacay)', 'Hotel Mina', 'Booster',
                        'Camisas', 'Ex Inia', 'Mauro', 'Caimanes', 'Agro Chungo',
                        'Monte Aranda', 'Chacay']

df = df[columnas_a_conservar]

# %%
df
# Out:
#       Mes   Año      Fecha  Vivero (Agrochacay)  Hotel Mina  Booster  Camisas  \
# 0       1  2003 2003-01-01                -99.0       -99.0    -99.0    -99.0
# 1       1  2003 2003-01-02                -99.0       -99.0    -99.0    -99.0
# 2       1  2003 2003-01-03                -99.0       -99.0    -99.0    -99.0
# 3       1  2003 2003-01-04                -99.0       -99.0    -99.0    -99.0
# 4       1  2003 2003-01-05                -99.0       -99.0    -99.0    -99.0
# ...   ...   ...        ...                  ...         ...      ...      ...
# 7665   12  2023 2023-12-27                  6.0         8.3      6.1      7.4
# 7666   12  2023 2023-12-28                  5.5         6.6      5.4      5.0
# 7667   12  2023 2023-12-29                  7.9         7.1      7.2      7.7
# 7668   12  2023 2023-12-30                  6.8         7.1      6.7      7.3
# 7669   12  2023 2023-12-31                  8.3         6.4      8.8      8.2
#
# ...

# %%
#cambiar nombre de columna 'Unnamed: 5' por 'Mes_año'
df.rename(columns={'AÑO':'Año'}, inplace=True)
# Out:
# C:\Users\fdona\AppData\Local\Temp\ipykernel_21676\742399269.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'AÑO':'Año'}, inplace=True)

# %%
columnas_a_modificar = [
    'Choapa en Cuncumen', 'Choapa en Salamanca', 'Pupio en el Romero',
    'Cuncumen antes Junta Choapa', 'Sobrante en Piñadero', 'Chalinga en la Palmilla',
    'Choapa sobre Rio Valle', 'Cuncumen antes Bocatoma Canales', 'Chalinga en San Agustin',
    'Pupio ante Quebrada LlauLlau'
]

df[columnas_a_modificar] = df[columnas_a_modificar].replace(['s.d.', 's.e.'], '-')

# %%
df
# Out:
#       Mes   Año      Fecha  Vivero (Agrochacay)  Hotel Mina  Booster  Camisas  \
# 0       1  2003 2003-01-01                -99.0       -99.0    -99.0    -99.0
# 1       1  2003 2003-01-02                -99.0       -99.0    -99.0    -99.0
# 2       1  2003 2003-01-03                -99.0       -99.0    -99.0    -99.0
# 3       1  2003 2003-01-04                -99.0       -99.0    -99.0    -99.0
# 4       1  2003 2003-01-05                -99.0       -99.0    -99.0    -99.0
# ...   ...   ...        ...                  ...         ...      ...      ...
# 7665   12  2023 2023-12-27                  6.0         8.3      6.1      7.4
# 7666   12  2023 2023-12-28                  5.5         6.6      5.4      5.0
# 7667   12  2023 2023-12-29                  7.9         7.1      7.2      7.7
# 7668   12  2023 2023-12-30                  6.8         7.1      6.7      7.3
# 7669   12  2023 2023-12-31                  8.3         6.4      8.8      8.2
#
# ...

# %%
df.to_excel('Analisis_devolucion_comunidad_compilado.xlsx', index=False)

# %%
import pandas as pd

# Leer el archivo Excel
archivo_excel = r"G:\.shortcut-targets-by-id\1ugEph6zRyoKHbwpiYuXbB3Pj0UXueIKJ\09. Contrato CS115 EIA 2024\03.WIP\02.Hidrología\01 Linea Base\02 Variables 2024\Temperatura\Gradientes_Text_Relleno_2003-2024_CIGF_HT.xlsx"


#
import pandas as pd



# Leer la hoja "T max" comenzando desde la fila 1 (índice 0 sería la primera fila)
df_t_max = pd.read_excel(archivo_excel, sheet_name='T max', skiprows=1)

# Mostrar el DataFrame para verificar que se ha leído correctamente
print("DataFrame 'T max' leído desde la fila 1:")
df_t_max.columns
# Out:
# DataFrame 'T max' leído desde la fila 1:
# Index(['AÑO', 'MES', 'DIA', 'FECHA', 'AgroChacay', 'Chacay', 'Cuncumen',
#        'HITO', 'Hotel Mina', 'Hualtatas', 'NIM', 'Pelambres', 'Punta Chungo',
#        'Quillay', 'Caimanes', 'Illapel DGA', 'La Tranquilla', 'Los Condores',
#        'Soldado', 'Mauro MLP', 'Caimanes MLP', 'Camisas',
#        'Ex Inia (17-03-2023)', 'Coiron (17-03-2023)', 'Booster (17-03-2023)',
#        'Chacay (17-03-2023)', 'Hotel Mina (17-03-2023)',
#        'Agro Chungo (17-03-2023)', 'AgroChacay.1', 'Chacay.1', 'Cuncumen.1',
#        'HITO.1', 'Hotel Mina.1', 'Hualtatas.1', 'NIM.1', 'Pelambres.1',
#        'Punta Chungo.1', 'Quillay.1', 'Caimanes.1', 'Illapel DGA.1',
#        'La Tranquilla.1', 'Los Condores.1', 'Soldado.1', 'Mauro MLP.1',
#        'Caimanes MLP.1', 'Camisas.1', 'Coiron', 'Agro Chungo', 'Booster',
#        'Ex-inia', 'Quelen Alto', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53',
#        'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57',
# ...
